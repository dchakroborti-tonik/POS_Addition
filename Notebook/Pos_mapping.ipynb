# %% [markdown]
# # <center> SIL POS Entry </center>

# %%
# Import Library

import pandas as pd 
import numpy as np 

from google.cloud import bigquery
import os

path = r"C:\Users\DwaipayanChakroborti\AppData\Roaming\gcloud\legacy_credentials\dchakroborti@tonikbank.com\adc.json"

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = path
client = bigquery.Client(project="prj-prod-dataplatform")

# %%
df = pd.read_csv(r"D:\OneDrive - Tonik Financial Pte Ltd\MyStuff\SIL Sales\Shin Nebria\SIL_Posadd_20240412.csv")
df
# Out:
#                  POS NAME STORE LOCATION           STATUS DATE ACTIVATION  \
# 0  Affordables Kaia Homes     Standalone  POS Operational  April 12, 2024
#
#   PURPLE KEY             REGION            TSM
# 0    MRHLEK9  South Luzon 1 (B)  Ricky Sarayno

# %%
# Mapping function to apply conditions
def map_brand_category(x):
    if 'Homeworks' in x:
        return 'Homeworks'
    elif 'Workstation' in x:
        return 'Workstation'
    elif 'Jhunpyo' in x:
        return 'Jhunpyo'
    elif 'Xtreme' in x:
        return 'Xtreme'
    elif 'Affordables' in x:
        return 'Affordables'
    elif 'Faith Glorious' in x:
        return 'Faith Glorious'
    elif 'FC Home' in x:
        return 'FC Home'
    elif 'A2RJ' in x:
        return 'A2RJ'
    elif 'ESLA' in x:
        return 'ESLA'
    elif 'JTG' in x:
        return 'JTG'
    elif 'KUM Home' in x:
        return 'KUM Home'
    elif 'Willy and Sons' in x:
        return 'Willy & Sons'
    elif 'PHPS' in x:
        return 'PHPS'
    elif 'Junliz' in x:
        return 'Junliz'
    elif 'Home Factory' in x:
        return 'Home Factory'
    elif 'Sogo Home' in x:
        return 'Sogo Home'
    elif 'Home Along' in x:
        return 'Home Along'
    elif 'Power Mac Center' in x:
        return 'Power Mac Center'
    elif 'Affordables' in x:
        return 'Affordables '
    else:
        return 'Other'

# Apply the mapping function to create a new 'BrandStores' column
df['BrandStores'] = df['POS NAME'].apply(map_brand_category)

# Display the updated DataFrame
df
# Out:
#                  POS NAME STORE LOCATION           STATUS DATE ACTIVATION  \
# 0  Affordables Kaia Homes     Standalone  POS Operational  April 12, 2024
#
#   PURPLE KEY             REGION            TSM  BrandStores
# 0    MRHLEK9  South Luzon 1 (B)  Ricky Sarayno  Affordables

# %%
df['BrandStores'].value_counts()
# Out:
# BrandStores
# Affordables    1
# Name: count, dtype: int64

# %%
df['PURPLE KEY'].value_counts()
# Out:
# PURPLE KEY
# MRHLEK9    1
# Name: count, dtype: int64

# %%
# df['BrandStores'] = df['POS NAME'].apply(lambda x: 'Faith Glorious' if 'Faith Glorious' in x else 'FC Home')
# df

# %%
df = df[['BrandStores', 'POS NAME', 'STORE LOCATION', 'STATUS', 'DATE ACTIVATION', 'PURPLE KEY', 'REGION', 'TSM']]
df
# Out:
#    BrandStores                POS NAME STORE LOCATION           STATUS  \
# 0  Affordables  Affordables Kaia Homes     Standalone  POS Operational
#
#   DATE ACTIVATION PURPLE KEY             REGION            TSM
# 0  April 12, 2024    MRHLEK9  South Luzon 1 (B)  Ricky Sarayno

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BrandStores      1 non-null      object
#  1   POS NAME         1 non-null      object
#  2   STORE LOCATION   1 non-null      object
#  3   STATUS           1 non-null      object
#  4   DATE ACTIVATION  1 non-null      object
#  5   PURPLE KEY       1 non-null      object
#  6   REGION           1 non-null      object
#  7   TSM              1 non-null      object
# dtypes: object(8)
# memory usage: 192.0+ bytes

# %%
df.rename(columns={'POS NAME':'POS', 'DATE ACTIVATION':'DateOpened', 'STORE LOCATION': 'StoreLocation', 'STATUS':'Status', 'PURPLE KEY':'PurpleKey', 'REGION':'Region'}, inplace = True)

# %%
import pandas as pd

df['DateOpened'] = pd.to_datetime(df['DateOpened'], format='%B %d, %Y')

# %%
print(df['DateOpened'].dtype)
# datetime64[ns]
# Out:
# datetime64[ns]

# %%
print(df['DateOpened'].iloc[0]) 
# 2024-01-15 00:00:00
# Out:
# 2024-04-12 00:00:00

# %%
df['DateOpened'] = df['DateOpened'].dt.strftime('%Y-%m-%d')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   BrandStores    1 non-null      object
#  1   POS            1 non-null      object
#  2   StoreLocation  1 non-null      object
#  3   Status         1 non-null      object
#  4   DateOpened     1 non-null      object
#  5   PurpleKey      1 non-null      object
#  6   Region         1 non-null      object
#  7   TSM            1 non-null      object
# dtypes: object(8)
# memory usage: 192.0+ bytes

# %%
df['DateOpened'] = pd.to_datetime(df['DateOpened'], format='%Y-%m-%d')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   BrandStores    1 non-null      object
#  1   POS            1 non-null      object
#  2   StoreLocation  1 non-null      object
#  3   Status         1 non-null      object
#  4   DateOpened     1 non-null      datetime64[ns]
#  5   PurpleKey      1 non-null      object
#  6   Region         1 non-null      object
#  7   TSM            1 non-null      object
# dtypes: datetime64[ns](1), object(7)
# memory usage: 192.0+ bytes

# %%
df.head()
# Out:
#    BrandStores                     POS StoreLocation           Status  \
# 0  Affordables  Affordables Kaia Homes    Standalone  POS Operational
#
#   DateOpened PurpleKey             Region            TSM
# 0 2024-04-12   MRHLEK9  South Luzon 1 (B)  Ricky Sarayno

# %%
sq = """drop table if exists prj-prod-dataplatform.dap_ds_poweruser_playground.POS_TSM_MAPIING1;"""
client.query(sq)
sq = """select * from prj-prod-dataplatform.dap_ds_poweruser_playground.POS_TSM_MAPIING1;"""
try:
    d = client.query(sq).to_dataframe(progress_bar_type='tqdm')
    print("Table still exists")
except:
    print("Table dropped")
# Out:
# Query is running:   0%|          |Table dropped

# %%
sq = """create table prj-prod-dataplatform.dap_ds_poweruser_playground.POS_TSM_MAPIING1
as 
select * from prj-prod-dataplatform.dap_ds_poweruser_playground.POS_TSM_MAPIING;
"""
client.query(sq)
# Out:
# QueryJob<project=prj-prod-dataplatform, location=asia-southeast1, id=e2b36487-0aa8-4cec-aab4-1c802c0d7431>

# %%
sq = """select * from prj-prod-dataplatform.dap_ds_poweruser_playground.POS_TSM_MAPIING1;"""
d = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of d is:\t{d.shape}")
# Out:
# Job ID 30f93d5b-df32-4f08-a5f4-fa7c89dc9a24 successfully executed: 100%|██████████|
# Query is running:   0%|          |
# Downloading: 100%|██████████|
# The shape of d is:	(326, 8)

# %%
sq = """select * from prj-prod-dataplatform.dap_ds_poweruser_playground.POS_TSM_MAPIING1"""

dfsil = client.query(sq).to_dataframe(progress_bar_type = 'tqdm')
# Out:
# Job ID 5d6f5065-3076-435e-8e30-8c2ef90c3ce4 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|

# %%
dfsil.BrandStores.value_counts()
# Out:
# BrandStores
# FC Home             108
# Home Along           90
# ESLA                 30
# Homeworks            13
# Xtreme               13
# Automatic Centre     11
# Kservico             10
# Faith Glorious        9
# Jhunpyo               8
# Workstation           6
# Power Mac Center      5
# Sogo Home             3
# Willy & Sons          3
# A2RJ                  3
# Hardware Sugar        2
# KUM Home Center       2
# PHPS                  2
# Junliz                2
# Home Factory          2
# Affordables           1
# Dizon Furniture       1
# JTG                   1
# KUM Home              1
# Name: count, dtype: int64

# %%
dfsil.shape
# Out:
# (326, 8)

# %%
# Set table_id to the ID of the table to append to.
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.POS_TSM_MAPIING1"

job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND"
)

job = client.load_table_from_dataframe(
    df, table_id, job_config=job_config
)  

job.result()  # Wait for the job to complete.

table = client.get_table(table_id)  # Make an API request.
print(
    "Loaded {} rows and {} columns to {}".format(
        table.num_rows, len(table.schema), table_id
    )
)
# Out:
# Loaded 327 rows and 8 columns to prj-prod-dataplatform.dap_ds_poweruser_playground.POS_TSM_MAPIING1

# %%
sq = """select * from prj-prod-dataplatform.dap_ds_poweruser_playground.POS_TSM_MAPIING1"""
df = client.query(sq).to_dataframe(progress_bar_type = 'tqdm')
print(f"The shape of the dataframe is: {df.shape}")
# Out:
# Job ID f73ba588-323c-4b49-9542-87de09a36a49 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is: (327, 8)

# %%
df.tail(10)
# Out:
#      BrandStores                                          POS  StoreLocation  \
# 317      FC Home                     FC Home Center Cabuyao 1     Standalone
# 318      FC Home                      FC Home Center Sta Cruz     Standalone
# 319      FC Home                     FC Home Center San Pablo     Standalone
# 320      FC Home                       FC Home Center Mamatid     Standalone
# 321      FC Home                      FC Home Center Siniloan     Standalone
# 322  Workstation  Workstation Home Appliances Pavilion Mall 1  Pavillon Mall
# 323  Workstation     Workstation Home Appliances Central Mall   Central Mall
# 324  Workstation      Workstation Home Appliances Target Mall    Target Mall
# 325       Xtreme                    Xtreme Appliances Calamba    Carmel Mall
# 326  Affordables                       Affordables Kaia Homes     Standalone
#
#               Status  DateOpened PurpleKey             Region  \
# 317  POS Operational  2023-09-14   M5D8JOH      South Luzon 2
# 318  POS Operational  2023-09-14   M1ZYHKU      South Luzon 2
# 319  POS Operational  2023-09-14   MADP0JZ      South Luzon 2
# 320  POS Operational  2023-09-14   MC31AV7      South Luzon 2
# 321  POS Operational  2023-09-15   MANB6XQ      South Luzon 2
# 322  POS Operational  2023-10-13   MN8MWPJ      South Luzon 2
# 323  POS Operational  2023-10-13   MTNCOR5      South Luzon 2
# 324  POS Operational  2023-10-13   M8I4QGT      South Luzon 2
# 325  POS Operational  2023-10-15   MUBPW04      South Luzon 2
# 326  POS Operational  2024-04-12   MRHLEK9  South Luzon 1 (B)
#
#                          TSM
# 317  Christian Klide Alberto
# 318  Christian Klide Alberto
# 319  Christian Klide Alberto
# 320  Christian Klide Alberto
# 321  Christian Klide Alberto
# 322  Christian Klide Alberto
# 323  Christian Klide Alberto
# 324  Christian Klide Alberto
# 325  Christian Klide Alberto
# 326            Ricky Sarayno

# %%
df['BrandStores'].value_counts()
# Out:
# BrandStores
# FC Home             108
# Home Along           90
# ESLA                 30
# Homeworks            13
# Xtreme               13
# Automatic Centre     11
# Kservico             10
# Faith Glorious        9
# Jhunpyo               8
# Workstation           6
# Power Mac Center      5
# Sogo Home             3
# Willy & Sons          3
# A2RJ                  3
# Hardware Sugar        2
# Affordables           2
# KUM Home Center       2
# PHPS                  2
# Junliz                2
# Home Factory          2
# Dizon Furniture       1
# JTG                   1
# KUM Home              1
# Name: count, dtype: int64

# %%
# Find duplicate values in 'POS' column
duplicates = df[df.duplicated('POS', keep=False)]

# Print the entire rows for duplicate entries in 'POS'
if not duplicates.empty:
    print("Duplicate values in 'POS' column:")
    duplicates.to_csv("Temp.csv")
else:
    print("No duplicate values found in 'POS' column.")
    
dd = pd.read_csv("Temp.csv")
dd.sort_values(by='POS')
# Out:
# Duplicate values in 'POS' column:
#     Unnamed: 0     BrandStores                         POS StoreLocation  \
# 0            1  Hardware Sugar       Hardware Sugar Makati           NaN
# 1            2  Hardware Sugar       Hardware Sugar Makati           NaN
# 12         289      Home Along          Home Along - Mayon    Standalone
# 13         290      Home Along          Home Along - Mayon    Standalone
# 14         295      Home Along         Home Along Malanday           NaN
# 15         296      Home Along         Home Along Malanday    Standalone
# 4          211      Home Along       Home Along Muntinlupa    Standalone
# 5          213      Home Along       Home Along Muntinlupa    Standalone
# 7          223      Home Along  Home Along Puregold Taguig    Standalone
# 10         226      Home Along  Home Along Puregold Taguig    Standalone
# 2           56      Home Along           Home Along Tumana    Standalone
# 3           58      Home Along           Home Along Tumana    Standalone
# 6          222      Home Along          Home Along Tunasan    Standalone
# 9          225      Home Along          Home Along Tunasan    Standalone
# 8          224      Home Along  Home Along Waterfun Taguig    Standalone
# 11         227      Home Along  Home Along Waterfun Taguig    Standalone
#
#              Status  DateOpened PurpleKey       Region                    TSM
# 0               NaN  2022-07-04   MV4UO0X          NaN                    NaN
# 1               NaN  2022-07-04   M9ZK6IU          NaN                    NaN
# 12  POS Operational  2022-07-01   MN3GL66  NCR North 2  Ben Antonio Lacsamana
# 13  POS Operational  2022-07-01   MGP2AQI    NCR North  Ben Antonio Lacsamana
# 14              NaN  2022-07-11   MURFAIV    NCR North  Ben Antonio Lacsamana
# 15  POS Operational  2022-07-11   MNBW4RZ    NCR North  Ben Antonio Lacsamana
# 4   POS Operational  2022-03-26   MDGYHQJ    NCR South   Klein Justine Tamayo
# 5   POS Operational  2022-03-26   MU82X9Z    NCR South   Klein Justine Tamayo
# 7   POS Operational  2022-07-01   MRGP0WQ    NCR South   Klein Justine Tamayo
# 10  POS Operational  2022-07-01   MDO3KI4    NCR South   Klein Justine Tamayo
# 2   POS Operational  2022-07-01   MS2WCNL     NCR East           Charm Moltio
# 3   POS Operational  2022-07-01   MBL3GTJ     NCR East           Charm Moltio
# 6   POS Operational  2022-07-01   MAGJHBV    NCR South   Klein Justine Tamayo
# 9   POS Operational  2022-07-01   MTI6M5S    NCR South   Klein Justine Tamayo
# 8   POS Operational  2022-07-01   MTH0X9L    NCR South   Klein Justine Tamayo
# 11  POS Operational  2022-07-01   MJX19GT    NCR South   Klein Justine Tamayo

# %%
pd.set_option('display.max_rows', None)
# Count the occurrences of each value in the 'PurpleKey' column
purple_key_counts = df['PurpleKey'].value_counts()

# Filter to include only values with count >= 2
filtered_counts = purple_key_counts[purple_key_counts >= 2]

# Display the filtered counts
print(filtered_counts)
# Out:
# Series([], Name: count, dtype: int64)

# %%
df[df['PurpleKey']== 'MRHLEK9']
# Out:
#      BrandStores                     POS StoreLocation           Status  \
# 326  Affordables  Affordables Kaia Homes    Standalone  POS Operational
#
#      DateOpened PurpleKey             Region            TSM
# 326  2024-04-12   MRHLEK9  South Luzon 1 (B)  Ricky Sarayno

# %%
sq = """drop table prj-prod-dataplatform.dap_ds_poweruser_playground.POS_TSM_MAPIING;"""

client.query(sq)
# Out:
# QueryJob<project=prj-prod-dataplatform, location=asia-southeast1, id=ec50373d-cddf-4d73-a24e-d1e5091a9793>

# %%
sq = """create table prj-prod-dataplatform.dap_ds_poweruser_playground.POS_TSM_MAPIING as select * from prj-prod-dataplatform.dap_ds_poweruser_playground.POS_TSM_MAPIING1;"""
client.query(sq)
# Out:
# QueryJob<project=prj-prod-dataplatform, location=asia-southeast1, id=cc2936a6-4824-414b-8a4b-6f1cc0cd0077>

# %%
client.query("commit")
# Out:
# QueryJob<project=prj-prod-dataplatform, location=US, id=d4b30a32-c5b7-40ad-b4b5-79dc885a4a57>

# %%
sq = """select * from prj-prod-dataplatform.dap_ds_poweruser_playground.POS_TSM_MAPIING;"""

df = client.query(sq).to_dataframe(progress_bar_type='tqdm')
df.shape
# Out:
# Job ID 3615b16f-c924-4b17-8af1-431d0f9b665a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# (327, 8)

# %%
df[df['BrandStores']=='Affordables']
# Out:
#     BrandStores                     POS StoreLocation           Status  \
# 61  Affordables       Affordables Tanza    Standalone      For Opening
# 64  Affordables  Affordables Kaia Homes    Standalone  POS Operational
#
#     DateOpened PurpleKey             Region            TSM
# 61  2024-01-22   M52OI1K  South Luzon 1 (B)  Ricky Sarayno
# 64  2024-04-12   MRHLEK9  South Luzon 1 (B)  Ricky Sarayno

# %%
df.head(10)
# Out:
#        BrandStores                                    POS StoreLocation  \
# 0           Xtreme                Xtreme Appliances Anabu          None
# 1   Hardware Sugar                  Hardware Sugar Makati          None
# 2   Hardware Sugar                  Hardware Sugar Makati          None
# 3       Home Along                    Home Along Sumulong          None
# 4  Dizon Furniture            Dizon Furniture Tiendesitas          None
# 5   Faith Glorious  Faith Glorious Fit Sales Center Pasig    Standalone
# 6        Homeworks                    Homeworks Montalban    Standalone
# 7          Jhunpyo                         Jhunpyo Teresa    Standalone
# 8          Jhunpyo                     Jhunpyo Binangonan    Standalone
# 9       Home Along                Home Along Binangonan 1    Standalone
#
#             Status  DateOpened PurpleKey    Region           TSM
# 0             None  2022-08-27   MR2YDE8      None          None
# 1             None  2022-07-04   M9ZK6IU      None          None
# 2             None  2022-07-04   MV4UO0X      None          None
# 3             None  2022-07-12   M2G78K4      None          None
# 4             None  2022-07-23   MOE3JQH      None          None
# 5      For Opening  2024-01-15   M4K2RFU  NCR East  Charm Moltio
# 6      For Opening  2024-01-22   M3XCD5W  NCR East  Charm Moltio
# 7      For Opening  2024-01-22   M6WHPE8  NCR East  Charm Moltio
# 8      For Opening  2024-01-22   MCS7VWN  NCR East  Charm Moltio
# 9  POS Operational  2023-05-19   ML9Z65B  NCR East  Charm Moltio

# %%
df.sort_values('DateOpened', ascending=False)
# Out:
#           BrandStores                                            POS  \
# 64        Affordables                         Affordables Kaia Homes
# 147        Home Along                          Home Along Concepcion
# 145        Home Along                              Home Along Tarlac
# 146        Home Along                      Home Along Paniqui Tarlac
# 93   Power Mac Center            Power Mac Center Festival Supermall
# 92   Power Mac Center                    Power Mac Center Manila Bay
# 108  Power Mac Center                    Power Mac Center Cloverleaf
# 202  Power Mac Center                     Power Mac Center Greenbelt
# 107  Power Mac Center            Power Mac Center Robinsons Magnolia
# 144           FC Home                          FC Home Center Guimba
# 104      Home Factory                   Home Factory Outlet Fairview
# 106         Sogo Home                              Sogo Home Zabarte
# 105         Sogo Home                              Sogo Home Alimall
# 101         Sogo Home                       Sogo Home Galleria South
# 196      Home Factory                Home Factory Outlet Mandaluyong
# 103            Junliz                         Junliz Nova Plaza Mall
# 102            Junliz                 Junliz Paso De Blas Valenzuela
# 99               PHPS                                  PHPS Bay Area
# 100              PHPS                                 PHPS San Pablo
# 115      Willy & Sons                            Willy and Sons Lipa
# 113      Willy & Sons                        Willy and Sons Batangas
# 114      Willy & Sons                         Willy and Sons Balayan
# 98             Xtreme         Xtreme Appliances Target Mall Sta Rosa
# 304          KUM Home              KUM Home Center Happy Tan Ternate
# 188         Homeworks                              Homeworks Malabon
# 189               JTG                            JTG Trading Kaybiga
# 22               ESLA                                ESLA Marikina 1
# 185              ESLA                         ESLA Proper Novaliches
# 186              ESLA                                   ESLA Zabarte
# 187              ESLA                                   ESLA Camarin
# 190              ESLA                                 ESLA Sta Maria
# 20               ESLA                               ESLA Montalban 1
# 183              ESLA                                    ESLA Susano
# 112              ESLA                                    ESLA Lipa 2
# 111              ESLA                                   ESLA Nasugbu
# 110              ESLA                          ESLA Rosario Batangas
# 109              ESLA                                    ESLA Lipa 1
# 23               ESLA                                   ESLA Pasig 3
# 62               ESLA                            ESLA Rosario Cavite
# 137              ESLA                                    ESLA Apalit
# 184              ESLA                             ESLA Bagong Silang
# 21               ESLA                               ESLA San Mateo 1
# 94               ESLA                                 ESLA Los Banos
# 30               ESLA                                    ESLA Taytay
# 24               ESLA                                ESLA Marikina 2
# 25               ESLA                                  ESLA Antipolo
# 26               ESLA                                    ESLA Morong
# 27               ESLA                               ESLA Montalban 2
# 95               ESLA                                ESLA Santa Rosa
# 29               ESLA                          ESLA Binangonan Bayan
# 28               ESLA                                     ESLA Cogeo
# 31               ESLA                                   ESLA Pasig 2
# 97               ESLA                                ESLA Santa Cruz
# 182              ESLA                                   ESLA Baesa 1
# 303              ESLA                                       ESLA GMA
# 96               ESLA                                 ESLA San Pedro
# 181         Homeworks                                Homeworks Sauyo
# 12          Homeworks                         Homeworks Pinagbuhatan
# 13               A2RJ                    A2RJ Telecom Guitnang Bayan
# 14               A2RJ                             A2RJ Telecom Ampid
# 16          Homeworks                               Homeworks Taytay
# 15               A2RJ                         A2RJ Telecom Montalban
# 194         Homeworks                              Homeworks Pateros
# 6           Homeworks                            Homeworks Montalban
# 7             Jhunpyo                                 Jhunpyo Teresa
# 8             Jhunpyo                             Jhunpyo Binangonan
# 61        Affordables                              Affordables Tanza
# 259         Homeworks                                Homeworks Baesa
# 258         Homeworks                         Homeworks Commonwealth
# 257         Homeworks                             Homeworks Malanday
# 136           Jhunpyo                                 Jhunpyo Tarlac
# 300         Homeworks                               Homeworks Silang
# 92                               Ayala Mall Manila Bay      For Opening
# 108                              Ayala Mall Cloverleaf      For Opening
# 202                                 Ayala Mall Circuit      For Opening
# 107                                 Robinsons Magnolia      For Opening
# 144                                         Standalone  POS Operational
# 104                                         Standalone      For Opening
# 106                                         Standalone      For Opening
# 105                                      Alimall Cubao      For Opening
# 101                                         Standalone      For Opening
# 196                                         Standalone      For Opening
# 103                                    Nova Plaza Mall      For Opening
# 102                                         Standalone      For Opening
# 99                                          Standalone      For Opening
# 100                                         Standalone      For Opening
# 115                                         Standalone      For Opening
# 113                                         Standalone      For Opening
# 114                                         Standalone      For Opening
# 98                                Target Mall Sta Rosa      For Opening
# 304                                         Standalone      For Opening
# 188                                         Standalone      For Opening
# 189                                         Standalone      For Opening
# 22                                          Standalone      For Opening
# 185                                         Standalone      For Opening
# 186                                Zabarte Town Center      For Opening
# 187                                         Standalone      For Opening
# 190                                         Standalone      For Opening
# 20                                          Standalone      For Opening
# 183                                         Standalone      For Opening
# 112                                         Standalone      For Opening
# 111                                         Standalone      For Opening
# 110                                         Standalone      For Opening
# 109                                         Standalone      For Opening
# 23                                          Standalone      For Opening
# 62                                          Standalone      For Opening
# 137                                         Standalone      For Opening
# 184                                         Standalone      For Opening
# 21                                          Standalone      For Opening
# 94                                          Standalone      For Opening
# 30                                          Standalone      For Opening
# 24                                          Standalone      For Opening
# 25                                          Standalone      For Opening
# 26                                          Standalone      For Opening
# 27                                          Standalone      For Opening
# 95                                          Standalone      For Opening
# 29                                          Standalone      For Opening
# 28                                          Standalone      For Opening
# 31                                          Standalone      For Opening
# 97                                          Standalone      For Opening
# 182                                         Standalone      For Opening
# 303                                         Standalone      For Opening
# 96                                          Standalone      For Opening
# 181                                         Standalone      For Opening
# 12                                          Standalone      For Opening
# 13                                          Standalone      For Opening
# 14                                          Standalone      For Opening
# 16                                          Standalone      For Opening
# 15                                          Standalone      For Opening
# 194                                         Standalone      For Opening
# 6                                           Standalone      For Opening
# 7                                           Standalone      For Opening
# 8                                           Standalone      For Opening
# 61                                          Standalone      For Opening
# 259                                         Standalone      For Opening
# 258                                  Ever Gotesco Mall      For Opening
# 257                                         Standalone      For Opening
# 136                                         Standalone      For Opening
# 300                                         Standalone      For Opening
# 299                                Districy Mall Dasma      For Opening
# 298                               Robinsons Place Imus      For Opening
# 260                                         Standalone      For Opening
# 255                                         Standalone      For Opening
# 256                                         Standalone      For Opening
# 191                                         Standalone      For Opening
# 192                                         Standalone      For Opening
# 5                                           Standalone      For Opening
# 193                                         Standalone      For Opening
# 254                                         Standalone      For Opening
# 252                                         Standalone      For Opening
# 135                                         Standalone      For Opening
# 251                                         Standalone      For Opening
# 253                                         Standalone      For Opening
# 250                                 Central Mall Dasma  POS Operational
# 74                                          Standalone  POS Operational
# 249                                         Standalone  POS Operational
# 248                                         Standalone  POS Operational
# 222                                         Standalone  POS Operational
# 180                                         Standalone  POS Operational
# 179                                    Robinsons Gapan  POS Operational
# 134                                         Standalone  POS Operational
# 326                                        Carmel Mall  POS Operational
# 323                                        Target Mall  POS Operational
# 324                                      Pavillon Mall  POS Operational
# 325                                       Central Mall  POS Operational
# 221                                         Standalone  POS Operational
# 177                                         Standalone  POS Operational
# 178                                         Standalone  POS Operational
# 173                                         Standalone  POS Operational
# 174                                         Standalone  POS Operational
# 247                                         Standalone  POS Operational
# 322                                         Standalone  POS Operational
# 220                                         Standalone  POS Operational
# 55                                          Standalone  POS Operational
# 176                                         Standalone  POS Operational
# 246                                         Standalone  POS Operational
# 175                                         Standalone  POS Operational
# 171                                         Standalone  POS Operational
# 321                                         Standalone  POS Operational
# 320                                         Standalone  POS Operational
# 319                                         Standalone  POS Operational
# 318                                Central Mall Laguna  POS Operational
# 317                                         Standalone  POS Operational
# 133                                         Standalone  POS Operational
# 132                                         Standalone  POS Operational
# 131                                         Standalone  POS Operational
# 130                                         Standalone  POS Operational
# 129                                         Standalone  POS Operational
# 128                                         Standalone  POS Operational
# 127                                         Standalone  POS Operational
# 126                                         Standalone  POS Operational
# 125                                         Standalone  POS Operational
# 124                                         Standalone  POS Operational
# 123                                         Standalone  POS Operational
# 54                                          Standalone  POS Operational
# 53                                          Standalone  POS Operational
# 52                                          Standalone  POS Operational
# 51                                          Standalone  POS Operational
# 50                                          Standalone  POS Operational
# 122                                         Standalone  POS Operational
# 285                                Malabon Citi Square  POS Operational
# 172                                         Standalone  POS Operational
# 169                                         Standalone  POS Operational
# 168                                        Marque Mall  POS Operational
# 170                                         Standalone  POS Operational
# 167                                         Standalone  POS Operational
# 166                                         Standalone  POS Operational
# 121                                         Standalone  POS Operational
# 165                                         Standalone  POS Operational
# 164                                         Standalone  POS Operational
# 215                                 Ayala Mall Circuit  POS Operational
# 161                                         Standalone  POS Operational
# 216                                  Guadalupe Complex  POS Operational
# 217                                         Standalone  POS Operational
# 218                                      SM Muntinlupa  POS Operational
# 219                                         Standalone  POS Operational
# 243                                         Standalone  POS Operational
# 244                                         Standalone  POS Operational
# 245                                         Standalone  POS Operational
# 282                                         Standalone  POS Operational
# 283                                        SM Sta Mesa  POS Operational
# 284                                         Standalone  POS Operational
# 313                                         Standalone  POS Operational
# 314                                 Robinson San Pedro  POS Operational
# 315                                         Standalone  POS Operational
# 316                                         Standalone  POS Operational
# 162                                         Standalone  POS Operational
# 163                                         Standalone  POS Operational
# 160                                         Standalone  POS Operational
# 90                                          Standalone  POS Operational
# 120                                         Standalone  POS Operational
# 119                                         Standalone  POS Operational
# 118                                         Standalone  POS Operational
# 117                                         Standalone  POS Operational
# 116                                         Standalone  POS Operational
# 91                               SM San Jose Del Monte  POS Operational
# 45                                          Standalone  POS Operational
# 43                                          Standalone  POS Operational
# 46                                          Standalone  POS Operational
# 47                               Choice Market Ortigas  POS Operational
# 48                                          Standalone  POS Operational
# 49                                          Standalone  POS Operational
# 159                                         Standalone  POS Operational
# 72                                          Standalone  POS Operational
# 44                                          Standalone  POS Operational
# 89                                          Standalone  POS Operational
# 73                             Robinsons General Trias  POS Operational
# 158                                         Standalone  POS Operational
# 155                                         Standalone  POS Operational
# 156                                         Standalone  POS Operational
# 157                                    SM San Fernando  POS Operational
# 279                                         Standalone  POS Operational
# 235                                         Standalone  POS Operational
# 234                                         Standalone  POS Operational
# 69                                          Standalone  POS Operational
# 35                                          Standalone  POS Operational
# 67                                          Standalone  POS Operational
# 66                                          Standalone  POS Operational
# 65                                          Standalone  POS Operational
# 60   LOT 5 BLK 9 GARNET ST. RHINELAND COMMERCIAL CO...      Operational
# 233                                         Standalone  POS Operational
# 232                                         Standalone  POS Operational
# 33                                          Standalone  POS Operational
# 34                                          Standalone  POS Operational
# 68                                          Standalone  POS Operational
# 38                                          Standalone  POS Operational
# 271                                         Standalone  POS Operational
# 311                                         Standalone  POS Operational
# 37                                          Standalone  POS Operational
# 36                                          Standalone  POS Operational
# 307                                         Standalone  POS Operational
# 308                                         Standalone  POS Operational
# 309                                        Target Mall  POS Operational
# 310                                         Standalone  POS Operational
# 79                                          Standalone  POS Operational
# 272                                         Standalone  POS Operational
# 278                                         Standalone  POS Operational
# 277                                         Standalone  POS Operational
# 276                                         Standalone  POS Operational
# 275                                         Standalone  POS Operational
# 274                                         Standalone  POS Operational
# 273                                         Standalone  POS Operational
# 270                                         Standalone  POS Operational
# 70                                          Standalone  POS Operational
# 86                                          Standalone  POS Operational
# 148                                         Standalone  POS Operational
# 205                                         Standalone  POS Operational
# 206                                         Standalone  POS Operational
# 207                           Market Place Mandaluyong  POS Operational
# 208                                         Standalone  POS Operational
# 209                                         Standalone  POS Operational
# 84                                          Standalone  POS Operational
# 85                                          Standalone  POS Operational
# 203                                         Standalone  POS Operational
# 82                                          Standalone  POS Operational
# 81                             Market Place Meycauayan  POS Operational
# 210                                         Standalone  POS Operational
# 83                                          Standalone  POS Operational
# 204                                         Standalone  POS Operational
# 80                                          Standalone  POS Operational
# 150                                         Standalone  POS Operational
# 151                                         Standalone  POS Operational
# 152                                         Standalone  POS Operational
# 149                                         Standalone  POS Operational
# 153                                         Standalone  POS Operational
# 154                                         Standalone  POS Operational
# 201                                         Standalone  POS Operational
# 269                                       Gateway Mall  POS Operational
# 267                                      SM North Edsa  POS Operational
# 268                                      Eastwood Mall  POS Operational
# 32                                     Sta. Lucia Mall  POS Operational
# 199                                Alabang Town Center  POS Operational
# 266                                           Ali Mall  POS Operational
# 265                                            Trinoma  POS Operational
# 197                                      Festival Mall  POS Operational
# 198                                      Market Market  POS Operational
# 200                                        Glorietta 1  POS Operational
# 264   #205 Mayon Street Brgy. Sta Teresita Quezon City      Operational
# 138                                         Standalone  POS Operational
# 139                                         Standalone  POS Operational
# 140                                         Standalone  POS Operational
# 141                                         Standalone  POS Operational
# 142                                         Standalone  POS Operational
# 143                                         Standalone  POS Operational
# 305                                         Standalone  POS Operational
# 306                                         Standalone  POS Operational
# 229                                         Standalone  POS Operational
# 78                                          Standalone  POS Operational
# 77                                          Standalone  POS Operational
# 19                                          Standalone  POS Operational
# 18                                          Standalone  POS Operational
# 17                                          Standalone  POS Operational
# 195                                         Standalone  POS Operational
# 263                                         Standalone  POS Operational
# 262                                         Standalone  POS Operational
# 76                                          Standalone  POS Operational
# 75                                          Standalone  POS Operational
# 9                                           Standalone  POS Operational
# 10                                          Standalone  POS Operational
# 11                                          Standalone  POS Operational
# 261                                         Standalone  POS Operational
# 301                                         Standalone  POS Operational
# 302                                         Standalone  POS Operational
# 40                                          Standalone  POS Operational
# 312                                         Standalone  POS Operational
# 87                                          Standalone  POS Operational
# 240                                         Standalone  POS Operational
# 239                                         Standalone  POS Operational
# 88                                          Standalone  POS Operational
# 238                                         Standalone  POS Operational
# 237                                         Standalone  POS Operational
# 39                                          Standalone  POS Operational
# 236                                         Standalone  POS Operational
# 71                                          Standalone  POS Operational
# 230                                         Standalone  POS Operational
# 231                                         Standalone  POS Operational
# 63                                          Standalone  POS Operational
# 0                                                 None             None
# 4                                                 None             None
# 3                                                 None             None
# 296                                         Standalone  POS Operational
# 297                                               None             None
# 295                                         Standalone  POS Operational
# 59                                          Standalone  POS Operational
# 294                                         Standalone  POS Operational
# 1                                                 None             None
# 292                                         Standalone  POS Operational
# 2                                                 None             None
# 293                                         Standalone  POS Operational
# 227                                         Standalone  POS Operational
# 57                                          Standalone  POS Operational
# 58                                          Standalone  POS Operational
# 223                                         Standalone  POS Operational
# 224                                         Standalone  POS Operational
# 225                                         Standalone  POS Operational
# 226                                         Standalone  POS Operational
# 56                                          Standalone  POS Operational
# 291                                         Standalone  POS Operational
# 286                                         Standalone  POS Operational
# 287                                         Standalone  POS Operational
# 288                                         Standalone  POS Operational
# 289                                         Standalone  POS Operational
# 290                                         Standalone  POS Operational
# 228                                         Standalone  POS Operational
# 280                                         Standalone  POS Operational
# 241                                         Standalone  POS Operational
# 281                                         Standalone  POS Operational
# 213                                         Standalone  POS Operational
# 212                                         Standalone  POS Operational
# 211                                         Standalone  POS Operational
# 214                                         Standalone  POS Operational
# ...
# 220  2023-09-15   MUCEDGY          NCR South     Klein Justine Tamayo
# 55   2023-09-15   MOR9J8P           NCR East             Charm Moltio
# 176  2023-09-15   M9TQV86      North Luzon 1        Rachelle Belmonte
# 246  2023-09-15   MIKWRBL  South Luzon 1 (B)     Sam Marlou Gatmaitan
# 175  2023-09-15   MSOAIC0      North Luzon 1        Rachelle Belmonte
# 171  2023-09-14   M9VWA8S      North Luzon 1        Rachelle Belmonte
# 321  2023-09-14   M5D8JOH      South Luzon 2  Christian Klide Alberto
# 320  2023-09-14   M1ZYHKU      South Luzon 2  Christian Klide Alberto
# 319  2023-09-14   MC31AV7      South Luzon 2  Christian Klide Alberto
# 318  2023-09-14   MYRK3EJ      South Luzon 2  Christian Klide Alberto
# 317  2023-09-14   MADP0JZ      South Luzon 2  Christian Klide Alberto
# 133  2023-09-14   M9X31A6      South Luzon 3        Jan jan Dela Cruz
# 132  2023-09-14   M7SE4LZ      South Luzon 3        Jan jan Dela Cruz
